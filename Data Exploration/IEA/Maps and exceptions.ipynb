# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.colors as colors

from datetime import datetime

import gmaps

gmaps.configure(api_key="AIzaSyAnubumevhate_wi70P93UM550PckRfLW0")

# %% [markdown]
# ## Loading and preparing the data

# %%
stop_events = pd.read_csv("../data_files/B/once/stop_events_with_geo_averages.csv", parse_dates=[1, 5, 6, 18, 19])

stop_events.head()
# Out:
#           id       date      stopCode         aimedArrival  \
# 0  167_101_1 2018-09-18  1200BOB20156  2018-09-18 07:03:00
# 1  167_101_1 2018-09-18  1200BOB20155  2018-09-18 07:04:00
# 2  167_101_1 2018-09-18  1200BOB20153  2018-09-18 07:05:00
# 3  167_101_1 2018-09-18  1200BOB20151  2018-09-18 07:07:00
# 4  167_101_1 2018-09-18  1200BOB20148  2018-09-18 07:08:00
#
#         aimedDeparture       actualArrival     actualDeparture  vehicle  \
# 0  2018-09-18 07:03:00 2018-09-18 07:02:25 2018-09-18 07:02:30      186
# 1  2018-09-18 07:04:00 2018-09-18 07:02:48 2018-09-18 07:02:53      186
# 2  2018-09-18 07:05:00 2018-09-18 07:03:11 2018-09-18 07:03:16      186
# 3  2018-09-18 07:07:00 2018-09-18 07:03:58 2018-09-18 07:04:51      186
# 4  2018-09-18 07:08:00 2018-09-18 07:05:34 2018-09-18 07:05:39      186
#
#       workid patternId  \
# 0  167_101_1    167_79
# 1  167_101_1    167_79
# 2  167_101_1    167_79
# 3  167_101_1    167_79
# 4  167_101_1    167_79
#
#                                    ...                                   \
# 0                                  ...
# 1                                  ...
# 2                                  ...
# 3                                  ...
# 4                                  ...
#
#   median_dwell_prev_by_stop_code_and_hour  \
# 0                                     9.0
# 1                                     4.0
# 2                                     5.0
# 3                                    32.5
# 4                                    46.0
#
#    median_dwell_dest_by_stop_code_and_hour_and_day  \
# 0                                              4.0
# 1                                              5.0
# 2                                             38.0
# 3                                             44.0
# 4                                              6.0
#
#   median_dwell_prev_by_stop_code_and_hour_and_day  \
# 0                                             6.0
# 1                                             4.0
# 2                                             5.0
# 3                                            38.0
# 4                                            44.0
#
#   median_full_durations_by_segment_code  \
# 0                                  46.0
# 1                                  23.0
# 2                                  44.0
# 3                                  82.0
# 4                                 103.0
#
#   median_full_durations_by_segment_code_and_hour  \
# 0                                           38.0
# 1                                           22.0
# 2                                           23.0
# 3                                           79.0
# 4                                           97.0
#
#   median_full_durations_by_segment_code_and_hour_and_day  \
# 0                                               37.0
# 1                                               21.0
# 2                                               24.0
# 3                                               86.5
# 4                                              100.0
#
#   diff_full_segment_and_median_by_segment_code  \
# 0                                        -24.0
# 1                                          0.0
# 2                                        -21.0
# 3                                        -35.0
# 4                                         -7.0
#
#    diff_full_segment_and_median_by_segment_code_and_hour_and_day  \
# 0                                              -15.0
# 1                                                2.0
# 2                                               -1.0
# 3                                              -39.5
# 4                                               -4.0
#
#   diff_percent_full_segment_and_median_by_segment_code  \
# 0                                         -52.173913
# 1                                           0.000000
# 2                                         -47.727273
# 3                                         -42.682927
# 4                                          -6.796117
#
#   diff_percent_full_segment_and_median_by_segment_code_and_hour_and_day
# 0                                         -40.540541
# 1                                           9.523810
# 2                                          -4.166667
# 3                                         -45.664740
# 4                                          -4.000000
#
# [5 rows x 59 columns]

# %%
stops = pd.read_csv("../Trapeze_Data/Stops.csv")

# %%
stop_events["aimedArrival"] = stop_events["aimedArrival"].astype("datetime64[ns]")
stop_events["aimedDeparture"] = stop_events["aimedDeparture"].astype("datetime64[ns]")
stop_events["prev_aimedArrival"] = stop_events["prev_aimedArrival"].astype("datetime64[ns]")
stop_events["prev_aimedDeparture"] = stop_events["prev_aimedDeparture"].astype("datetime64[ns]")
stop_events["prev_actualArrival"] = stop_events["prev_actualArrival"].astype("datetime64[ns]")
stop_events["prev_actualDeparture"] = stop_events["prev_actualDeparture"].astype("datetime64[ns]")



# stop_events.head(30)

# print(stop_events.shape)

# stop_events = stop_events.dropna(axis=0)

# # # stop_events = stop_events[stop_events.id != "NaN"]

# print(stop_events.shape)
# Out:
# (4231677, 59)
# (4227841, 59)

# %%
stop_events.head(5)
# Out:
#           id       date      stopCode        aimedArrival      aimedDeparture  \
# 0  167_101_1 2018-09-18  1200BOB20156 2018-09-18 07:03:00 2018-09-18 07:03:00
# 1  167_101_1 2018-09-18  1200BOB20155 2018-09-18 07:04:00 2018-09-18 07:04:00
# 2  167_101_1 2018-09-18  1200BOB20153 2018-09-18 07:05:00 2018-09-18 07:05:00
# 3  167_101_1 2018-09-18  1200BOB20151 2018-09-18 07:07:00 2018-09-18 07:07:00
# 4  167_101_1 2018-09-18  1200BOB20148 2018-09-18 07:08:00 2018-09-18 07:08:00
#
#         actualArrival     actualDeparture  vehicle     workid patternId  \
# 0 2018-09-18 07:02:25 2018-09-18 07:02:30      186  167_101_1    167_79
# 1 2018-09-18 07:02:48 2018-09-18 07:02:53      186  167_101_1    167_79
# 2 2018-09-18 07:03:11 2018-09-18 07:03:16      186  167_101_1    167_79
# 3 2018-09-18 07:03:58 2018-09-18 07:04:51      186  167_101_1    167_79
# 4 2018-09-18 07:05:34 2018-09-18 07:05:39      186  167_101_1    167_79
#
#                                    ...                                   \
# 0                                  ...
# 1                                  ...
# 2                                  ...
# 3                                  ...
# 4                                  ...
#
#   median_dwell_prev_by_stop_code_and_hour  \
# 0                                     9.0
# 1                                     4.0
# 2                                     5.0
# 3                                    32.5
# 4                                    46.0
#
#    median_dwell_dest_by_stop_code_and_hour_and_day  \
# 0                                              4.0
# 1                                              5.0
# 2                                             38.0
# 3                                             44.0
# 4                                              6.0
#
#   median_dwell_prev_by_stop_code_and_hour_and_day  \
# 0                                             6.0
# 1                                             4.0
# 2                                             5.0
# 3                                            38.0
# 4                                            44.0
#
#   median_full_durations_by_segment_code  \
# 0                                  46.0
# 1                                  23.0
# 2                                  44.0
# 3                                  82.0
# 4                                 103.0
#
#   median_full_durations_by_segment_code_and_hour  \
# 0                                           38.0
# 1                                           22.0
# 2                                           23.0
# 3                                           79.0
# 4                                           97.0
#
#   median_full_durations_by_segment_code_and_hour_and_day  \
# 0                                               37.0
# 1                                               21.0
# 2                                               24.0
# 3                                               86.5
# 4                                              100.0
#
#   diff_full_segment_and_median_by_segment_code  \
# 0                                        -24.0
# 1                                          0.0
# 2                                        -21.0
# 3                                        -35.0
# 4                                         -7.0
#
#    diff_full_segment_and_median_by_segment_code_and_hour_and_day  \
# 0                                              -15.0
# 1                                                2.0
# 2                                               -1.0
# 3                                              -39.5
# 4                                               -4.0
#
#   diff_percent_full_segment_and_median_by_segment_code  \
# 0                                         -52.173913
# 1                                           0.000000
# 2                                         -47.727273
# 3                                         -42.682927
# 4                                          -6.796117
#
#   diff_percent_full_segment_and_median_by_segment_code_and_hour_and_day
# 0                                         -40.540541
# 1                                           9.523810
# 2                                          -4.166667
# 3                                         -45.664740
# 4                                          -4.000000
#
# [5 rows x 59 columns]

# %% [markdown]
# ### Looking at journeys back in time

# %%
total_time_travelers = stop_events[stop_events.actualArrival < stop_events.prev_actualDeparture].count()['id']

print(f"Out of {stop_events.shape[0]} stop events {total_time_travelers} go backawards in time.")
print(f"This represents {total_time_travelers*100/stop_events.shape[0]:0.5f}%")
# Out:
# Out of 4227841 stop events 163 go backawards in time.
# This represents 0.00386%

# %%
stop_events.loc[stop_events.actualArrival < stop_events.prev_actualDeparture].head(5)
# Out:
#                 id       date      stopCode        aimedArrival  \
# 44823      167_8_1 2018-09-18  1280POA90816 2018-09-18 07:21:00
# 92880    167_760_2 2018-09-19  1280BOB20038 2018-09-19 08:09:00
# 100490  167_131_19 2018-09-20  1200BOB20147 2018-09-20 21:06:00
# 108116  167_211_11 2018-09-20  1290BOB20523 2018-09-20 15:22:00
# 133206  167_801_10 2018-09-20  1290DOB21210 2018-09-20 15:27:00
#
#             aimedDeparture       actualArrival     actualDeparture  vehicle  \
# 44823  2018-09-18 07:21:00 2018-09-18 07:17:39 2018-09-18 07:18:35      125
# 92880  2018-09-19 08:09:00 2018-09-19 08:15:25 2018-09-19 08:15:28      152
# 100490 2018-09-20 21:06:00 2018-09-20 21:04:50 2018-09-20 21:05:59      165
# 108116 2018-09-20 15:22:00 2018-09-20 15:23:20 2018-09-20 15:23:27      265
# 133206 2018-09-20 15:27:00 2018-09-20 15:28:22 2018-09-20 15:28:58      118
#
#             workid patternId  \
# 44823      167_8_1   167_133
# 92880    167_760_2   167_259
# 100490  167_131_19   167_106
# 108116  167_211_11   167_175
# 133206  167_801_10    167_72
#
#                                         ...                                   \
# 44823                                   ...
# 92880                                   ...
# 100490                                  ...
# 108116                                  ...
# 133206                                  ...
#
#        median_dwell_prev_by_stop_code_and_hour  \
# 44823                                      8.0
# 92880                                      6.0
# 100490                                   849.0
# 108116                                     9.0
# 133206                                    25.0
#
#         median_dwell_dest_by_stop_code_and_hour_and_day  \
# 44823                                              55.0
# 92880                                               4.0
# 100490                                              5.0
# 108116                                              5.0
# 133206                                              9.0
#
#        median_dwell_prev_by_stop_code_and_hour_and_day  \
# 44823                                              7.0
# 92880                                              6.0
# 100490                                           867.0
# 108116                                             9.5
# 133206                                            27.0
#
#        median_full_durations_by_segment_code  \
# 44823                                   11.0
# 92880                                   30.0
# 100490                                  57.0
# 108116                                  57.0
# 133206                                  36.0
#
#        median_full_durations_by_segment_code_and_hour  \
# 44823                                            11.0
# 92880                                            31.0
# 100490                                           43.5
# 108116                                           63.0
# 133206                                           41.0
#
#        median_full_durations_by_segment_code_and_hour_and_day  \
# 44823                                                10.0
# 92880                                                31.0
# 100490                                               44.0
# 108116                                               69.0
# 133206                                               45.0
#
#        diff_full_segment_and_median_by_segment_code  \
# 44823                                          -6.0
# 92880                                           4.0
# 100490                                        659.0
# 108116                                         25.0
# 133206                                         12.0
#
#         diff_full_segment_and_median_by_segment_code_and_hour_and_day  \
# 44823                                                -5.0
# 92880                                                 3.0
# 100490                                              672.0
# 108116                                               13.0
# 133206                                                3.0
#
#        diff_percent_full_segment_and_median_by_segment_code  \
# 44823                                          -54.545455
# 92880                                           13.333333
# 100490                                        1156.140351
# 108116                                          43.859649
# 133206                                          33.333333
#
#        diff_percent_full_segment_and_median_by_segment_code_and_hour_and_day
# 44823                                          -50.000000
# 92880                                            9.677419
# 100490                                        1527.272727
# 108116                                          18.840580
# 133206                                           6.666667
#
# [5 rows x 59 columns]

# %%
time_travelers = stop_events.loc[stop_events.actualArrival < stop_events.prev_actualDeparture].merge(stops, 'left', on=['stopCode'])

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(time_travelers[['lat','lon']]))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Looking at Journeys that took zero time

# %%
total_zero_time_travelers = stop_events[stop_events.actualArrival == stop_events.prev_actualDeparture].count()['id']

print(f"Out of {stop_events.shape[0]} stop events {total_zero_time_travelers} take zero time.")
print(f"This represents {total_zero_time_travelers*100/stop_events.shape[0]:0.5f}%")
# Out:
# Out of 4227841 stop events 3440 take zero time.
# This represents 0.08137%

# %%
stop_events.loc[stop_events.actualArrival == stop_events.prev_actualDeparture][['stopCode', 'prev_stopCode']].head(5)
# Out:
#           stopCode prev_stopCode
# 3344  1290BOB20426  1290BOB20435
# 3345  1290BOB20424  1290BOB20426
# 3346  1290BOB20415  1290BOB20424
# 3347  1290BOB20414  1290BOB20415
# 3348  1290BOB20412  1290BOB20414

# %%
zero_timers = stop_events.loc[stop_events.actualArrival == stop_events.prev_actualDeparture].merge(stops, 'left', on=['stopCode'])

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(zero_timers[['lat','lon']]))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Looking at journeys that take over 10 minutes

# %%
total_slow_coaches = stop_events[((stop_events.actualArrival - stop_events.prev_actualDeparture).astype('timedelta64[s]') > 600)].count()['id']

print(f"Out of {stop_events.shape[0]} stop events {total_slow_coaches} journeys take over 10 minutes.")
print(f"This represents {total_slow_coaches*100/stop_events.shape[0]:0.4f}%")
# Out:
# Out of 4227841 stop events 1617 journeys take over 10 minutes.
# This represents 0.0382%

# %%
stop_events.loc[((stop_events.actualArrival - stop_events.prev_actualDeparture).astype('timedelta64[s]') > 600)].head(5)
# Out:
#                id       date      stopCode        aimedArrival  \
# 3262    167_143_8 2018-09-18  1200DOY38562 2018-09-18 12:46:00
# 11345  167_217_11 2018-09-18  1290DOB21131 2018-09-18 14:22:00
# 12813   167_221_1 2018-09-18  1290BOB20003 2018-09-18 07:37:00
# 13045  167_221_15 2018-09-18  1290DOB21131 2018-09-18 20:02:00
# 13933   167_222_6 2018-09-18  1290BOA05335 2018-09-18 12:18:00
#
#            aimedDeparture       actualArrival     actualDeparture  vehicle  \
# 3262  2018-09-18 12:46:00 2018-09-18 12:58:19 2018-09-18 12:58:30      185
# 11345 2018-09-18 14:22:00 2018-09-18 14:23:26 2018-09-18 14:24:15      237
# 12813 2018-09-18 07:37:00 2018-09-18 07:49:30 2018-09-18 07:49:39      127
# 13045 2018-09-18 20:02:00 2018-09-18 20:05:11 2018-09-18 20:05:18      127
# 13933 2018-09-18 12:22:00 2018-09-18 12:24:30 2018-09-18 12:27:13      113
#
#            workid patternId  \
# 3262    167_143_8    167_91
# 11345  167_217_11   167_220
# 12813   167_221_1   167_235
# 13045  167_221_15   167_220
# 13933   167_222_6   167_220
#
#                                        ...                                   \
# 3262                                   ...
# 11345                                  ...
# 12813                                  ...
# 13045                                  ...
# 13933                                  ...
#
#       median_dwell_prev_by_stop_code_and_hour  \
# 3262                                      7.0
# 11345                                     7.0
# 12813                                    40.0
# 13045                                     6.0
# 13933                                    23.0
#
#        median_dwell_dest_by_stop_code_and_hour_and_day  \
# 3262                                             492.0
# 11345                                              5.0
# 12813                                             41.0
# 13045                                              5.0
# 13933                                              7.0
#
#       median_dwell_prev_by_stop_code_and_hour_and_day  \
# 3262                                             16.5
# 11345                                             7.0
# 12813                                            47.0
# 13045                                             6.0
# 13933                                            14.0
#
#       median_full_durations_by_segment_code  \
# 3262                                   55.0
# 11345                                 164.0
# 12813                                 102.0
# 13045                                 164.0
# 13933                                  85.0
#
#       median_full_durations_by_segment_code_and_hour  \
# 3262                                            62.0
# 11345                                          193.0
# 12813                                          111.0
# 13045                                           95.5
# 13933                                           99.0
#
#       median_full_durations_by_segment_code_and_hour_and_day  \
# 3262                                                63.0
# 11345                                              207.0
# 12813                                              141.0
# 13045                                               99.5
# 13933                                              100.5
#
#       diff_full_segment_and_median_by_segment_code  \
# 3262                                         891.0
# 11345                                        470.0
# 12813                                        979.0
# 13045                                        478.0
# 13933                                        684.0
#
#        diff_full_segment_and_median_by_segment_code_and_hour_and_day  \
# 3262                                               883.0
# 11345                                              427.0
# 12813                                              940.0
# 13045                                              542.5
# 13933                                              668.5
#
#       diff_percent_full_segment_and_median_by_segment_code  \
# 3262                                         1620.000000
# 11345                                         286.585366
# 12813                                         959.803922
# 13045                                         291.463415
# 13933                                         804.705882
#
#       diff_percent_full_segment_and_median_by_segment_code_and_hour_and_day
# 3262                                         1401.587302
# 11345                                         206.280193
# 12813                                         666.666667
# 13045                                         545.226131
# 13933                                         665.174129
#
# [5 rows x 59 columns]

# %%
slow_coaches = stop_events.loc[((stop_events.actualArrival - stop_events.prev_actualDeparture).astype('timedelta64[s]') > 600)].merge(stops, 'left', on=['stopCode'])

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(slow_coaches[['lat','lon']]))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Looking at all journeys

# %%
stop_events = stop_events.merge(stops, 'left', on=['stopCode'])

# %%
# fig = gmaps.figure()
# fig.add_layer(gmaps.heatmap_layer(stop_events[['lat','lon']]))
# fig

# %% [markdown]
# ### Looking at segments

# %%
just_segments = stop_events.drop_duplicates(subset=['segment_code'])

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(just_segments[['lat','lon']]))
fig
